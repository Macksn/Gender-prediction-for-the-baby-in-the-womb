# %% [markdown]
# # TR

# %%
import datetime

# Burçları belirlemek için fonksiyon
def burc_belirle(dogum_tarihi):
    gun = dogum_tarihi.day
    ay = dogum_tarihi.month
    
    if (ay == 3 and gun >= 21) or (ay == 4 and gun <= 20):
        return "Koç"
    elif (ay == 4 and gun >= 21) or (ay == 5 and gun <= 21):
        return "Boğa"
    elif (ay == 5 and gun >= 22) or (ay == 6 and gun <= 22):
        return "İkizler"
    elif (ay == 6 and gun >= 23) or (ay == 7 and gun <= 22):
        return "Yengeç"
    elif (ay == 7 and gun >= 23) or (ay == 8 and gun <= 22):
        return "Aslan"
    elif (ay == 8 and gun >= 23) or (ay == 9 and gun <= 23):
        return "Başak"
    elif (ay == 9 and gun >= 24) or (ay == 10 and gun <= 23):
        return "Terazi"
    elif (ay == 10 and gun >= 24) or (ay == 11 and gun <= 22):
        return "Akrep"
    elif (ay == 11 and gun >= 23) or (ay == 12 and gun <= 21):
        return "Yay"
    elif (ay == 12 and gun >= 22) or (ay == 1 and gun <= 20):
        return "Oğlak"
    elif (ay == 1 and gun >= 21) or (ay == 2 and gun <= 19):
        return "Kova"
    elif (ay == 2 and gun >= 20) or (ay == 3 and gun <= 20):
        return "Balık"

# Cinsiyeti belirlemek için fonksiyon
def cinsiyet_belirle(cevaplar):
    erkek_olasilik = 0
    kiz_olasilik = 0
    
    if cevaplar[0] == 0:
        kiz_olasilik += 60
        erkek_olasilik += 40
    else:
        kiz_olasilik += 40
        erkek_olasilik += 60

    if cevaplar[1] == 0:
        kiz_olasilik += 45
        erkek_olasilik += 55
    else:
        kiz_olasilik += 55
        erkek_olasilik += 45

    if cevaplar[2] == 0:
        kiz_olasilik += 52
        erkek_olasilik += 48
    else:
        kiz_olasilik += 48
        erkek_olasilik += 52

    if cevaplar[3] == 0:
        kiz_olasilik += 58
        erkek_olasilik += 42
    else:
        kiz_olasilik += 42
        erkek_olasilik += 58

    if cevaplar[4] == 0:
        kiz_olasilik += 43
        erkek_olasilik += 57
    else:
        kiz_olasilik += 57
        erkek_olasilik += 43
    
    if kiz_olasilik > erkek_olasilik:
        return "kız"
    else:
        return "erkek"

# İsim ve burç bilgileri
isimler = {
    "kız": {
        "Koç": ["Aylin", "Duru", "Eylül"],
        "Boğa": ["Elif", "Nehir", "Zeynep"],
        "İkizler": ["Ece", "Selin", "Mira"],
        "Yengeç": ["Ada", "Bade", "Ceren"],
        "Aslan": ["Elif", "Zeynep", "Naz"],
        "Başak": ["Derin", "Eylül", "Lara"],
        "Terazi": ["İpek", "Kumru", "Nazlı"],
        "Akrep": ["Aylin", "Duru", "Eylül"],
        "Yay": ["Elif", "Nehir", "Zeynep"],
        "Oğlak": ["Ece", "Selin", "Mira"],
        "Kova": ["Ada", "Bade", "Ceren"],
        "Balık": ["Elif", "Zeynep", "Naz"]
    },
    "erkek": {
        "Koç": ["Alp", "Deniz", "Ege"],
        "Boğa": ["Arda", "Eren", "Kerem"],
        "İkizler": ["Ege", "Deniz", "Arda"],
        "Yengeç": ["Bartu", "Kaan", "Mert"],
        "Aslan": ["Kerem", "Emir", "Alp"],
        "Başak": ["Deniz", "Efe", "Rüzgar"],
        "Terazi": ["Arda", "Can", "Efe"],
        "Akrep": ["Alp", "Deniz", "Ege"],
        "Yay": ["Arda", "Eren", "Kerem"],
        "Oğlak": ["Ege", "Deniz", "Arda"],
        "Kova": ["Bartu", "Kaan", "Mert"],
        "Balık": ["Kerem", "Emir", "Alp"]
    }
}

burc_spoiler = {
    "Koç": {
        "kız": "Enerjik, cesur ve maceracı bir yapıya sahip olacak.",
        "erkek": "Lider ruhlu, kararlı ve rekabetçi olacak."
    },
    "Boğa": {
        "kız": "Sadık, sabırlı ve güvenilir bir yapıya sahip olacak.",
        "erkek": "Pratik, güvenilir ve kararlı bir çocuk olacak."
    },
    "İkizler": {
        "kız": "Meraklı, enerjik ve sosyal bir yapıya sahip olacak.",
        "erkek": "Zeki, esprili ve meraklı bir çocuk olacak."
    },
    "Yengeç": {
        "kız": "Duygusal, şefkatli ve koruyucu bir yapıya sahip olacak.",
        "erkek": "Duygusal, sadık ve aileye düşkün bir çocuk olacak."
    },
    "Aslan": {
        "kız": "Özgüvenli, lider ruhlu ve yaratıcı olacak.",
        "erkek": "Karizmatik, cesur ve liderlik vasıflarına sahip olacak."
    },
    "Başak": {
        "kız": "Detaycı, düzenli ve çalışkan bir yapıya sahip olacak.",
        "erkek": "Pratik, analitik ve çalışkan bir çocuk olacak."
    },
    "Terazi": {
        "kız": "Nazik, adil ve sosyal bir yapıya sahip olacak.",
        "erkek": "Dengeli, adil ve uyumlu bir çocuk olacak."
    },
    "Akrep": {
        "kız": "Tutkulu, kararlı ve gizemli bir yapıya sahip olacak.",
        "erkek": "Güçlü, kararlı ve sezgisel bir çocuk olacak."
    },
    "Yay": {
        "kız": "Macera sever, özgürlüğüne düşkün ve neşeli bir yapıya sahip olacak.",
        "erkek": "Meraklı, özgürlüğüne düşkün ve açık fikirli bir çocuk olacak."
    },
    "Oğlak": {
        "kız": "Disiplinli, sorumluluk sahibi ve çalışkan bir yapıya sahip olacak.",
        "erkek": "Ciddi, kararlı ve hedef odaklı bir çocuk olacak."
    },
    "Kova": {
        "kız": "Özgür ruhlu, yenilikçi ve entelektüel bir yapıya sahip olacak.",
        "erkek": "Bağımsız, yaratıcı ve hümanist bir çocuk olacak."
    },
    "Balık": {
        "kız": "Duygusal, yaratıcı ve sezgisel bir yapıya sahip olacak.",
        "erkek": "Duygusal, empatik ve hayalperest bir çocuk olacak."
    }
}

# Kullanıcıdan veri alma
son_regl_tarihi = input("Son Regl Tarihinizi girin (YYYY-MM-DD): ")
sabah_bulantisi = int(input("Sabah bulantılarınız nasıl? (çok =0 /az=1): "))
aserme = int(input("Ne tür yiyecekler aşeriyorsunuz? (tatlı=0 /ekşi=1): "))
idrar_rengi = int(input("İdrar renginiz nasıl? (açık=0/koyu=1): "))
karin_sekli = int(input("Karın şekliniz nasıl ? (yuvarlak=0/sivri=1): "))
sac_rengi = int(input("Hamilelik süresince saçınız daha (koyu=0/açık=1): "))

cevaplar = [sabah_bulantisi, aserme, idrar_rengi, karin_sekli, sac_rengi]

# Doğum tarihi hesaplama
son_regl_tarihi_dt = datetime.datetime.strptime(son_regl_tarihi, "%Y-%m-%d")
dogum_tarihi = son_regl_tarihi_dt + datetime.timedelta(days=280)

# Cinsiyet ve burç belirleme
cinsiyet = cinsiyet_belirle(cevaplar)
burc = burc_belirle(dogum_tarihi)

# Sonuçların ekrana yazdırılması
print(f"Tebrikler {burc} burcu bir {cinsiyet} bebeğiniz olacak.")
print(f"İşte {burc} burcu {cinsiyet} çocuğunuz için birkaç isim önerisi: {', '.join(isimler[cinsiyet][burc])}")
print(f"{burc} Burcu {cinsiyet.capitalize()} Çocuk: {burc_spoiler[burc][cinsiyet]}")
# Out:
# Son Regl Tarihinizi girin (YYYY-MM-DD): 2024-05-10
# Sabah bulantılarınız nasıl? (çok =0 /az=1): 0
# Ne tür yiyecekler aşeriyorsunuz? (tatlı=0 /ekşi=1): 0
# İdrar renginiz nasıl? (açık=0/koyu=1): 1
# Karın şekliniz nasıl ? (yuvarlak=0/sivri=1): 1
# Hamilelik süresince saçınız daha (koyu=0/açık=1): 0
# Tebrikler Kova burcu bir erkek bebeğiniz olacak.
# İşte Kova burcu erkek çocuğunuz için birkaç isim önerisi: Bartu, Kaan, Mert
# Kova Burcu Erkek Çocuk: Bağımsız, yaratıcı ve hümanist bir çocuk olacak.

# %% [markdown]
# # EN

# %%
import datetime

# Function for determining bushings
def determine_horoscope(birth_date):
    days = birth_date.day
    months = birth_date.month
    
    if (months == 3 and days >= 21) or (months == 4 and days <= 20):
        return "Aries"
    elif (months == 4 and days >= 21) or (months == 5 and days <= 21):
        return "Taurus"
    elif (months == 5 and days >= 22) or (months == 6 and days <= 22):
        return "Gemini"
    elif (months == 6 and days >= 23) or (months == 7 and days <= 22):
        return "Cancer"
    elif (months == 7 and days >= 23) or (months == 8 and days <= 22):
        return "Leo"
    elif (months == 8 and days >= 23) or (months == 9 and days <= 23):
        return "Virgo"
    elif (months == 9 and days >= 24) or (months == 10 and days <= 23):
        return "Libra"
    elif (months == 10 and days >= 24) or (months == 11 and days <= 22):
        return "Scorpio"
    elif (months == 11 and days >= 23) or (months == 12 and days <= 21):
        return "Sagittarius"
    elif (months == 12 and days >= 22) or (months == 1 and days <= 20):
        return "Capricorn"
    elif (months == 1 and days >= 21) or (months == 2 and days <= 19):
        return "Aquarius"
    elif (months == 2 and days >= 20) or (months == 3 and days <= 20):
        return "Pisces"

# Function to determine gender
def determine_gender(answers):
    boy_possibility = 0
    girl_possibility = 0
    
    if answers[0] == 0:
        girl_possibility += 60
        boy_possibility += 40
    else:
        girl_possibility += 40
        boy_possibility += 60

    if answers[1] == 0:
        girl_possibility += 45
        boy_possibility += 55
    else:
        girl_possibility += 55
        boy_possibility += 45

    if answers[2] == 0:
        girl_possibility += 52
        boy_possibility += 48
    else:
        girl_possibility += 48
        boy_possibility += 52

    if answers[3] == 0:
        girl_possibility += 58
        boy_possibility += 42
    else:
        girl_possibility += 42
        boy_possibility += 58

    if answers[4] == 0:
        girl_possibility += 43
        boy_possibility += 57
    else:
        girl_possibility += 57
        boy_possibility += 43
    
    if girl_possibility > boy_possibility:
        return "girl"
    else:
        return "boy "

# Name and horoscope informations
names = {
    "girl": {
        "Aries": ["Amelia", "Maya", "Riley"],
        "Taurus": ["Charlotte", "Olivia", "Penelope"],
        "Gemini": ["Evelyn", "Sophia", "Stella"],
        "Cancer": ["Luna", "Mia", "Nora"],
        "Leo": ["Aurora", "Claire", "Scarlett"],
        "Virgo": ["Elizabeth", "Evelyn", "Harper"],
        "Libra": ["Avery", "Harper", "Riley"],
        "Scorpio": ["Evelyn", "Layla", "Maya"],
        "Sagittarius": ["Amelia", "Eva", "Evelyn"],
        "Capricorn": ["Olivia", "Penelope", "Sophia"],
        "Aquarius": ["Avery", "Luna", "Stella"],
        "Pisces": ["Evelyn", "Harper", "Maya"]
    },
    "boy": {
        "Aries": ["Alexander", "Ethan", "Leo"],
        "Taurus": ["Elijah", "Noah", "Owen"],
        "Gemini": ["Liam", "Logan", "Mason"],
        "Cancer": ["Benjamin", "Caleb", "Matthew"],
        "Leo": ["Julian", "Thedore", "William"],
        "Virgo": ["Michael", "Oliver", "Sebastian"],
        "Libra": ["Daniel", "Ethan", "Leo"],
        "Scorpio": ["Elijah", "Gabriel", "Lucas"],
        "Sagittarius": ["Archer", "Benjamin", "Noah"],
        "Capricorn": ["Alexander", "Elijah", "Owen"],
        "Aquarius": ["Ethan", "Liam", "Logan"],
        "Pisces": ["Josh", "Caleb", "Michael"]
    }
}

horoscope_spoiler = {
    "Aries": {
        "girl": "She will have an energetic, courageous and adventurous nature.",
        "boy": "He will be a leader, determined and competitive."
    },
    "Taurus": {
        "girl": "She will have a loyal, patient and reliable nature.",
        "boy": "He will be a practical, reliable and determined boy."
    },
    "Gemini": {
        "girl": "She will have a curious, energetic and sociable nature.",
        "boy": "He will be intelligent, witty and curious."
    },
    "Cancer": {
        "girl": "She will have an emotional, caring and protective nature.",
        "boy": "He will be emotional, loyal and devoted to his family."
    },
    "Leo": {
        "girl": "She will be self-confident, leader spirited and creative.",
        "boy": "He will be charismatic, courageous and have leadership qualities."
    },
    "Virgo": {
        "girl": "She will have a detached, organized and hardworking nature.",
        "boy": "He will be a practical, analytical and hardworking boy."
    },
    "Libra": {
        "girl": "She will have a kind, fair and social nature.",
        "boy": "He will be a balanced, fair and harmonious child."
    },
    "Scorpio": {
        "girl": "She will have a passionate, determined and mysterious nature.",
        "boy": "He will be a strong, determined and intuitive boy."
    },
    "Sagittarius": {
        "girl": "She will have an adventurous, freedom-loving and cheerful nature.",
        "boy": "He will be curious, independent and open-minded."
    },
    "Capricorn": {
        "girl": "She will have a disciplined, responsible and hardworking nature.",
        "boy": "He will be a serious, determined and goal-oriented child."
    },
    "Aquarius": {
        "girl": "She will be free-spirited, innovative and intellectual.",
        "boy": "He will be an independent, creative and humanistic child."
    },
    "Pisces": {
        "girl": "She will have an emotional, creative and intuitive nature.",
        "boy": "He will be an emotional, empathetic and imaginative child."
    }
}

# Retrieving data from the user
last_regl_date = input("Enter your Last Period Date (YYYY-MM-DD): ")
morning_nausea = int(input("How is your morning sickness? (much =0 / little =1): "))
craving = int(input("What kind of food do you crave? (sweet=0/sour=1): "))
urine_color = int(input("How is your urine color? (light=0/dark=1): "))
tummy_bump = int(input("How is your tummy shape? (round=0/sharp=1): "))
hair_color = int(input("During pregnancy, your hair becomes more (dark=0/light=1): "))

answers = [morning_nausea, craving, urine_color, tummy_bump, hair_color]

# Date of birth calculation
last_regl_date_dt = datetime.datetime.strptime(last_regl_date, "%Y-%m-%d")
birth_date = last_regl_date_dt + datetime.timedelta(days=280)

# Gender and zodiac sign determination
gender = determine_gender(answers)
zodiac = determine_horoscope(birth_date)

# Printing the results on the screen
print(f"Congratulations you are going to have a {zodiac} baby {gender} ")
print(f"here are name suggestions for your {zodiac} baby {gender} : {', '.join(names[gender][zodiac])}")
print(f"{zodiac} zodiac {gender.capitalize()} child: {horoscope_spoiler[zodiac][gender]}")
# Out:
# Enter your Last Period Date (YYYY-MM-DD): 2024-01-05
# How is your morning sickness? (much =0 / little =1): 0
# What kind of food do you crave? (sweet=0/sour=1): 1
# How is your urine color? (light=0/dark=1): 0
# How is your tummy shape? (round=0/sharp=1): 0
# During pregnancy, your hair becomes more (dark=0/light=1): 1
# Congratulations you are going to have a Libra baby girl
# here are name suggestions for your Libra baby girl : Avery, Harper, Riley
# Libra zodiac Girl child: She will have a kind, fair and social nature.
